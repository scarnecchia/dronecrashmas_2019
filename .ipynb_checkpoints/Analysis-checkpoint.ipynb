# %%
import networkx as nx
from pymongo import MongoClient
import pandas as pd
from pandas.io.json import json_normalize
import seaborn as sns
import json
from urllib.parse import urlsplit
from urllib.parse import urlparse
import requests
import http.client
import matplotlib.pyplot as plt
from newspaper import Article
import gc
import datetime as dt

# %%
client = MongoClient('mongodb://localhost:27017')
db = client["twitterdb"]
collection = db.droneCrashmas2019

# %%
#start = 'Sat 21 Dec 05:00:00 +0000 2019'
#end = 'Thu 31 Dec 05:00:00 +0000 2019'

# %%
#df = pd.DataFrame(list(collection.find(query)))

# %%
projection = {
        #convert created_at to date
        '$project': {
            '_id': 0, 
            'id': 1, 
            'created_at': {
                '$dateFromString': {
                    'dateString': '$created_at'
                }
            }, 
            'user': 1, 
            'entities': 1, 
            'lang': 1, 
            'text': 1, 
            'retweeted_status': 1
        }
    }

match = {
        '$match': {
            'created_at': {
                '$lte': dt.datetime(2020, 1, 1, 0, 0, 0, tzinfo=dt.timezone.utc)
            }
        }
    }

# %%
cursor = collection.aggregate([projection, match])
df =  pd.DataFrame(list(cursor))

# %%
df.shape
# Out:
# (844982, 7)

# %%
df.head()
# Out:
#                     id                                               text  \
# 0  1205944739150860289  RT @DKTechAmb: Technology can help solve real ...
# 1  1205944741680046080  RT @BabakTaghvaee: #BREAKING: Right now, #Liby...
# 2  1205944833472376833  @DTOMPKINS4 getting a bird's eye view of the d...
# 3  1205944794331189248  RT @newscientist: Many countries and groups al...
# 4  1205944792024276992                 @That1MiningGuy its crypto's drone
#
#                                                 user  \
# 0  {'id': 960353713, 'id_str': '960353713', 'name...
# 1  {'id': 3102416297, 'id_str': '3102416297', 'na...
# 2  {'id': 102467452, 'id_str': '102467452', 'name...
# 3  {'id': 309855109, 'id_str': '309855109', 'name...
# 4  {'id': 1203139992001875968, 'id_str': '1203139...
#
#                                     retweeted_status  \
# 0  {'created_at': 'Sat Dec 14 20:14:42 +0000 2019...
# 1  {'created_at': 'Fri Dec 13 18:22:55 +0000 2019...
# 2                                                NaN
# 3  {'created_at': 'Fri Dec 13 06:20:55 +0000 2019...
# 4                                                NaN
#
#                                             entities lang          created_at
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...   en 2019-12-14 20:16:45
# 1  {'hashtags': [{'text': 'BREAKING', 'indices': ...   en 2019-12-14 20:16:46
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...   en 2019-12-14 20:17:08
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...   en 2019-12-14 20:16:58
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...   en 2019-12-14 20:16:58

# %%
df['created_at'] = df['created_at'].dt.tz_localize('UTC')
df['created_at'] = df['created_at'].dt.tz_convert('US/Eastern')
df = df[(df['created_at'] >= '2019-12-21 00:00:00') & (df['created_at'] <= '2019-12-31 23:59:59')]
df['hour'] = df['created_at'].dt.hour
df['day_of_week'] = df['created_at'].dt.dayofweek
df.shape
# Out:
# (429445, 9)

# %% [markdown]
# MongoDB documents containing nested data need to be flattened. Here we extract the urls, hashtags, and mentioned users from entities using json_normalize:

# %%
#tweets_flat = json_normalize(df['entities'])
entities_data = json_normalize(df['entities'], record_path='urls', meta=['hashtags', 'user_mentions'], errors='ignore')
entities_data['protocol'],entities_data['domain'],entities_data['path'],entities_data['query'],entities_data['fragment'] = zip(*[urlsplit(x) for x in entities_data['expanded_url']])
df['domain'] = entities_data['domain']
df['url'] = entities_data['expanded_url']
#entities_data.drop(entities_data.index, inplace=True)
df.head(25)
# Out:
#                          id  \
# 415528  1208250774331023360
# 415531  1208250749710417921
# 415532  1208250775421554690
# 415533  1208250804760526848
# 415536  1208250827279884288
# 415538  1208250780261634049
# 415539  1208250889414332421
# 415540  1208250821827350528
# 415543  1208250808514433026
# 415544  1208250900692602880
# 415545  1208250864659386368
# 415546  1208251069077147648
# 415547  1208250953851424769
# 415548  1208250965406736384
# 415549  1208251068259426310
# 415550  1208251069798551552
# 415551  1208250947627036672
# 415552  1208250943353098240
# 415553  1208251076605927424
# 415554  1208250900118155264
# 415555  1208250944498159616
# 415556  1208251129525456897
# 415557  1208251191093805056
# 415558  1208251261067227136
# 415559  1208251211926781953
#
#                                                      text  \
# 415528  + the movie drones on the the bg, but you don’...
# 415531                               E Ba’ mi ooo e jooor
# 415532  From old school weapons (machetes, mechanical ...
# 415533  Turkey Deploys Armed Drones to Northern Cyprus...
# 415536  2019%20Drone%20U%20Christmas%20Giveaway https%...
# 415538  Drone alone 2 - the unexpected benefits https:...
# 415539  2019 Drone U Christmas Giveaway https://t.co/G...
# 415540  RT @MobilePunch: JAMB may deploy drones to mon...
# 415543  RT @pandit_cyber: Drones will reshape the futu...
# 415544  @muso1947 @denniallen @JoJomills13 @GladysB @J...
# 415545  RT @MCU_Direct: Official new #SpiderManFarFrom...
# 415546  ドローン機体情報、登録義務に。対象は200グラム以上。 https://t.co/QibUh...
# 415547  RT @tracyy00: الmtv مكملة عادي ببيت الكل ولا ك...
# 415548  RT @DJCHORABACON: @ops_caze @KNojinhoo Do jeit...
# 415549  Sudah siap berpetualang dengan mereka?\nAbadik...
# 415550  Internet/Mobile/Broadcast Bans. Drone Surveill...
# 415551  RT @34NorthDrones: Drone alone 2 - the unexpec...
# 415552  RT @Thomas_Binder: The psychopath who oversaw ...
# 415553  RT @pandit_cyber: Drones will reshape the futu...
# 415554  RT @Jimmyconwayy19: This conversation was the ...
# 415555  RT @ObzorOzor: MJX Bugs 5 W B5W 5G WIFI #fpv W...
# 415556  ‘Game-changer’ methanol battery keeps drone in...
# 415557  RT @BestBuy: Give the gift of flight. We’ve go...
# 415558  Also very happy to see people hating Basil Zem...
# 415559  RT @Ben_Westcott: Insane story - Chinese pig f...
#
#                                                      user  \
# 415528  {'id': 1206402265734623233, 'id_str': '1206402...
# 415531  {'id': 747166303, 'id_str': '747166303', 'name...
# 415532  {'id': 259356502, 'id_str': '259356502', 'name...
# 415533  {'id': 2202959839, 'id_str': '2202959839', 'na...
# 415536  {'id': 429947734, 'id_str': '429947734', 'name...
# 415538  {'id': 1101637134681665536, 'id_str': '1101637...
# 415539  {'id': 429947734, 'id_str': '429947734', 'name...
# 415540  {'id': 340582504, 'id_str': '340582504', 'name...
# 415543  {'id': 977050999000059905, 'id_str': '97705099...
# 415544  {'id': 1195529938582925313, 'id_str': '1195529...
# 415545  {'id': 1245093037, 'id_str': '1245093037', 'na...
# 415546  {'id': 985134984171216896, 'id_str': '98513498...
# 415547  {'id': 933719706355273733, 'id_str': '93371970...
# 415548  {'id': 990444676925808640, 'id_str': '99044467...
# 415549  {'id': 1156377217909186560, 'id_str': '1156377...
# 415550  {'id': 2505142580, 'id_str': '2505142580', 'na...
# 415551  {'id': 744773276254113792, 'id_str': '74477327...
# 415552  {'id': 144580542, 'id_str': '144580542', 'name...
# 415553  {'id': 1142424032794406912, 'id_str': '1142424...
# 415554  {'id': 476559000, 'id_str': '476559000', 'name...
# 415555  {'id': 839645523288145921, 'id_str': '83964552...
# 415556  {'id': 1101637134681665536, 'id_str': '1101637...
# 415557  {'id': 122783146, 'id_str': '122783146', 'name...
# 415558  {'id': 1099210748943728640, 'id_str': '1099210...
# 415559  {'id': 1158136940929019904, 'id_str': '1158136...
#
#                                          retweeted_status  \
# 415528                                                NaN
# 415531                                                NaN
# 415532                                                NaN
# 415533                                                NaN
# 415536                                                NaN
# 415538                                                NaN
# 415539                                                NaN
# 415540  {'created_at': 'Fri Dec 20 05:43:28 +0000 2019...
# 415543  {'created_at': 'Fri Dec 20 06:06:00 +0000 2019...
# 415544                                                NaN
# 415545  {'created_at': 'Fri Dec 20 21:08:32 +0000 2019...
# 415546                                                NaN
# 415547  {'created_at': 'Fri Dec 20 20:53:26 +0000 2019...
# 415548  {'created_at': 'Fri Dec 20 09:25:54 +0000 2019...
# 415549                                                NaN
# 415550                                                NaN
# 415551  {'created_at': 'Sat Dec 21 05:00:08 +0000 2019...
# 415552  {'created_at': 'Fri Dec 20 22:30:07 +0000 2019...
# 415553  {'created_at': 'Fri Dec 20 06:06:00 +0000 2019...
# 415554  {'created_at': 'Fri Dec 20 22:34:53 +0000 2019...
# 415555  {'created_at': 'Tue Dec 17 08:07:49 +0000 2019...
# 415556                                                NaN
# 415557  {'created_at': 'Tue Dec 03 18:31:16 +0000 2019...
# 415558                                                NaN
# 415559  {'created_at': 'Sat Dec 21 04:46:32 +0000 2019...
#
#                                                  entities lang  \
# 415528  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415531  {'hashtags': [], 'urls': [], 'user_mentions': ...   pt
# 415532  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415533  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415536  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415538  {'hashtags': [{'text': 'drone', 'indices': [64...   en
# 415539  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415540  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415543  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415544  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415545  {'hashtags': [{'text': 'SpiderManFarFromHome',...   en
# 415546  {'hashtags': [], 'urls': [{'url': 'https://t.c...   ja
# 415547  {'hashtags': [], 'urls': [], 'user_mentions': ...   ar
# 415548  {'hashtags': [], 'urls': [], 'user_mentions': ...   pt
# 415549  {'hashtags': [{'text': 'dji', 'indices': [77, ...   in
# 415550  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415551  {'hashtags': [{'text': 'drone', 'indices': [83...   en
# 415552  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415553  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415554  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415555  {'hashtags': [{'text': 'fpv', 'indices': [40, ...   en
# 415556  {'hashtags': [{'text': 'drone', 'indices': [92...   en
# 415557  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415558  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415559  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
#
#                       created_at  hour  day_of_week domain  url
# 415528 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415531 2019-12-21 00:00:01-05:00     0            5    NaN  NaN
# 415532 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415533 2019-12-21 00:00:14-05:00     0            5    NaN  NaN
# 415536 2019-12-21 00:00:20-05:00     0            5    NaN  NaN
# 415538 2019-12-21 00:00:08-05:00     0            5    NaN  NaN
# 415539 2019-12-21 00:00:34-05:00     0            5    NaN  NaN
# 415540 2019-12-21 00:00:18-05:00     0            5    NaN  NaN
# 415543 2019-12-21 00:00:15-05:00     0            5    NaN  NaN
# 415544 2019-12-21 00:00:37-05:00     0            5    NaN  NaN
# 415545 2019-12-21 00:00:29-05:00     0            5    NaN  NaN
# 415546 2019-12-21 00:01:17-05:00     0            5    NaN  NaN
# 415547 2019-12-21 00:00:50-05:00     0            5    NaN  NaN
# 415548 2019-12-21 00:00:53-05:00     0            5    NaN  NaN
# 415549 2019-12-21 00:01:17-05:00     0            5    NaN  NaN
# 415550 2019-12-21 00:01:17-05:00     0            5    NaN  NaN
# 415551 2019-12-21 00:00:48-05:00     0            5    NaN  NaN
# 415552 2019-12-21 00:00:47-05:00     0            5    NaN  NaN
# 415553 2019-12-21 00:01:19-05:00     0            5    NaN  NaN
# 415554 2019-12-21 00:00:37-05:00     0            5    NaN  NaN
# 415555 2019-12-21 00:00:48-05:00     0            5    NaN  NaN
# 415556 2019-12-21 00:01:32-05:00     0            5    NaN  NaN
# 415557 2019-12-21 00:01:46-05:00     0            5    NaN  NaN
# 415558 2019-12-21 00:02:03-05:00     0            5    NaN  NaN
# 415559 2019-12-21 00:01:51-05:00     0            5    NaN  NaN

# %%
#df = df[~df['text'].str.contains('iraq|afghanistan|libya|syria|airstrike|soleimani|suleimani|qaeda|terrorist', na=False)]
#df = df[~df['url'].str.contains('iraq|afghanistan|libya|syria|airstrike|soleimani|suleimani|qaeda|terrorist', na=False)]
#df.shape

# %%
# Out:
# (427828, 11)

# %% [markdown]
# Now we can parse the URL. I'm interested in unique domains, so for convience's sake, I'm placing that in a top level attribute column (are they called rows and columns with NoSQL?)

# %% [markdown]
# Now extracting screen names

# %%
user_flat = json_normalize(df['user'])
df['screen_name'] = user_flat['screen_name']
user_flat.drop(user_flat.index, inplace=True)

# %%
hashtag_data = json_normalize(df['entities'], record_path='hashtags', meta=['user_mentions', 'urls'], errors='ignore')
df['hashtags'] = hashtag_data['text']
hashtag_data.drop(hashtag_data.index, inplace=True)

# %%
#df = df[~df['url'].str.contains('sirios|refugiados-africanos|estado-islamico', na=False)].reset_index()
#df = df[~df['text'].str.contains('sírios|refugiados africanos|estado islâmico', na=False)].reset_index()

# %%
#df['lang'] = df['lang'].replace('en-gb', 'en-GB')
#df['lang'] = df['lang'].replace('en-GB', 'en')
#df_en = df.loc[df['lang'] == 'en']

# %%
df.to_csv('dronecrashmas.csv', encoding='utf-8')

# %%
language = pd.DataFrame()
language = df['lang'].reset_index(name='lang')
unique_lang = language.groupby('lang')['index'].nunique()
top10 = unique_lang.nlargest(10).reset_index()

# %%
df_top10 = df[df.lang.isin(top10['lang'])]
df_top10.head(10)
# Out:
#                          id  \
# 415528  1208250774331023360
# 415531  1208250749710417921
# 415532  1208250775421554690
# 415533  1208250804760526848
# 415536  1208250827279884288
# 415538  1208250780261634049
# 415539  1208250889414332421
# 415540  1208250821827350528
# 415543  1208250808514433026
# 415544  1208250900692602880
#
#                                                      text  \
# 415528  + the movie drones on the the bg, but you don’...
# 415531                               E Ba’ mi ooo e jooor
# 415532  From old school weapons (machetes, mechanical ...
# 415533  Turkey Deploys Armed Drones to Northern Cyprus...
# 415536  2019%20Drone%20U%20Christmas%20Giveaway https%...
# 415538  Drone alone 2 - the unexpected benefits https:...
# 415539  2019 Drone U Christmas Giveaway https://t.co/G...
# 415540  RT @MobilePunch: JAMB may deploy drones to mon...
# 415543  RT @pandit_cyber: Drones will reshape the futu...
# 415544  @muso1947 @denniallen @JoJomills13 @GladysB @J...
#
#                                                      user  \
# 415528  {'id': 1206402265734623233, 'id_str': '1206402...
# 415531  {'id': 747166303, 'id_str': '747166303', 'name...
# 415532  {'id': 259356502, 'id_str': '259356502', 'name...
# 415533  {'id': 2202959839, 'id_str': '2202959839', 'na...
# 415536  {'id': 429947734, 'id_str': '429947734', 'name...
# 415538  {'id': 1101637134681665536, 'id_str': '1101637...
# 415539  {'id': 429947734, 'id_str': '429947734', 'name...
# 415540  {'id': 340582504, 'id_str': '340582504', 'name...
# 415543  {'id': 977050999000059905, 'id_str': '97705099...
# 415544  {'id': 1195529938582925313, 'id_str': '1195529...
#
#                                          retweeted_status  \
# 415528                                                NaN
# 415531                                                NaN
# 415532                                                NaN
# 415533                                                NaN
# 415536                                                NaN
# 415538                                                NaN
# 415539                                                NaN
# 415540  {'created_at': 'Fri Dec 20 05:43:28 +0000 2019...
# 415543  {'created_at': 'Fri Dec 20 06:06:00 +0000 2019...
# 415544                                                NaN
#
#                                                  entities lang  \
# 415528  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415531  {'hashtags': [], 'urls': [], 'user_mentions': ...   pt
# 415532  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415533  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415536  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415538  {'hashtags': [{'text': 'drone', 'indices': [64...   en
# 415539  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415540  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415543  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415544  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
#
#                       created_at  hour  day_of_week domain  url  \
# 415528 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415531 2019-12-21 00:00:01-05:00     0            5    NaN  NaN
# 415532 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415533 2019-12-21 00:00:14-05:00     0            5    NaN  NaN
# 415536 2019-12-21 00:00:20-05:00     0            5    NaN  NaN
# 415538 2019-12-21 00:00:08-05:00     0            5    NaN  NaN
# 415539 2019-12-21 00:00:34-05:00     0            5    NaN  NaN
# 415540 2019-12-21 00:00:18-05:00     0            5    NaN  NaN
# 415543 2019-12-21 00:00:15-05:00     0            5    NaN  NaN
# 415544 2019-12-21 00:00:37-05:00     0            5    NaN  NaN
#
#            screen_name hashtags
# 415528          LVMXSS      NaN
# 415531    austinkojima      NaN
# 415532    thatonekimmy      NaN
# 415533     Dolphin1320      NaN
# 415536     mostafa_hey      NaN
# 415538   jusrinbaldwin      NaN
# 415539    Firewallj760      NaN
# 415540  GnashtyDamerch      NaN
# 415543       Super_FOG      NaN
# 415544          ddyllw      NaN

# %%
df.head(10)
# Out:
#                          id  \
# 415528  1208250774331023360
# 415531  1208250749710417921
# 415532  1208250775421554690
# 415533  1208250804760526848
# 415536  1208250827279884288
# 415538  1208250780261634049
# 415539  1208250889414332421
# 415540  1208250821827350528
# 415543  1208250808514433026
# 415544  1208250900692602880
#
#                                                      text  \
# 415528  + the movie drones on the the bg, but you don’...
# 415531                               e ba’ mi ooo e jooor
# 415532  from old school weapons (machetes, mechanical ...
# 415533  turkey deploys armed drones to northern cyprus...
# 415536  2019%20drone%20u%20christmas%20giveaway https%...
# 415538  drone alone 2 - the unexpected benefits https:...
# 415539  2019 drone u christmas giveaway https://t.co/g...
# 415540  rt @mobilepunch: jamb may deploy drones to mon...
# 415543  rt @pandit_cyber: drones will reshape the futu...
# 415544  @muso1947 @denniallen @jojomills13 @gladysb @j...
#
#                                                      user  \
# 415528  {'id': 1206402265734623233, 'id_str': '1206402...
# 415531  {'id': 747166303, 'id_str': '747166303', 'name...
# 415532  {'id': 259356502, 'id_str': '259356502', 'name...
# 415533  {'id': 2202959839, 'id_str': '2202959839', 'na...
# 415536  {'id': 429947734, 'id_str': '429947734', 'name...
# 415538  {'id': 1101637134681665536, 'id_str': '1101637...
# 415539  {'id': 429947734, 'id_str': '429947734', 'name...
# 415540  {'id': 340582504, 'id_str': '340582504', 'name...
# 415543  {'id': 977050999000059905, 'id_str': '97705099...
# 415544  {'id': 1195529938582925313, 'id_str': '1195529...
#
#                                          retweeted_status  \
# 415528                                                NaN
# 415531                                                NaN
# 415532                                                NaN
# 415533                                                NaN
# 415536                                                NaN
# 415538                                                NaN
# 415539                                                NaN
# 415540  {'created_at': 'Fri Dec 20 05:43:28 +0000 2019...
# 415543  {'created_at': 'Fri Dec 20 06:06:00 +0000 2019...
# 415544                                                NaN
#
#                                                  entities lang  \
# 415528  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415531  {'hashtags': [], 'urls': [], 'user_mentions': ...   pt
# 415532  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415533  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415536  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415538  {'hashtags': [{'text': 'drone', 'indices': [64...   en
# 415539  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415540  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415543  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 415544  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
#
#                       created_at  hour  day_of_week domain  url  \
# 415528 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415531 2019-12-21 00:00:01-05:00     0            5    NaN  NaN
# 415532 2019-12-21 00:00:07-05:00     0            5    NaN  NaN
# 415533 2019-12-21 00:00:14-05:00     0            5    NaN  NaN
# 415536 2019-12-21 00:00:20-05:00     0            5    NaN  NaN
# 415538 2019-12-21 00:00:08-05:00     0            5    NaN  NaN
# 415539 2019-12-21 00:00:34-05:00     0            5    NaN  NaN
# 415540 2019-12-21 00:00:18-05:00     0            5    NaN  NaN
# 415543 2019-12-21 00:00:15-05:00     0            5    NaN  NaN
# 415544 2019-12-21 00:00:37-05:00     0            5    NaN  NaN
#
#            screen_name hashtags
# 415528          LVMXSS      NaN
# 415531    austinkojima      NaN
# 415532    thatonekimmy      NaN
# 415533     Dolphin1320      NaN
# 415536     mostafa_hey      NaN
# 415538   jusrinbaldwin      NaN
# 415539    Firewallj760      NaN
# 415540  GnashtyDamerch      NaN
# 415543       Super_FOG      NaN
# 415544          ddyllw      NaN

# %%
parsed_urls = pd.DataFrame()
parsed_urls = df['domain'].reset_index(name='url')
unique = parsed_urls.groupby('url')['index'].nunique()
unique.nlargest(25)
# Out:
# Series([], Name: index, dtype: int64)

# %%
parsed_urls = pd.DataFrame()
parsed_urls = df['url'].reset_index(name='url')
unique_ful = parsed_urls.groupby('url')['index'].nunique()
unique_ful.nlargest(25)
# Out:
# Series([], Name: index, dtype: int64)

# %%
hashtag_data = json_normalize(df['entities'], record_path='hashtags', meta=['user_mentions', 'urls'], errors='ignore')
hashtags = pd.DataFrame()
hashtags = hashtag_data['text'].reset_index(name='hashtags')
utags = hashtags.groupby('hashtags')['index'].nunique()
utags.nlargest(25)
# Out:
# hashtags
# drone                     9172
# drones                    5972
# AI                        4325
# Drone                     3616
# Drones                    2690
# موسسه_مصاف_ایرانیان       2340
# uav                       2104
# Robotics                  1916
# Bolivia                   1797
# ドローン                      1720
# IoT                       1478
# happynewyear2020           979
# ArtificialIntelligence     969
# AmericanExpress            956
# V                          887
# IARTG                      863
# technology                 852
# BTSV                       815
# dji                        795
# Concours                   786
# Kindle                     773
# Amazon                     759
# México                     723
# tech                       720
# Books                      669
# Name: index, dtype: int64

# %%
user_count = pd.DataFrame()
user_count = df['screen_name'].reset_index(name='Screen Name')
user_count = user_count.groupby('Screen Name')['index'].nunique()
user_count.nlargest(25)
# Out:
# Screen Name
# AshTheThird        22
# _Generic__          9
# chuddles11          9
# oldwac1             9
# who_dat37           9
# DroneNewsFeed       8
# LucySullivan888     8
# MISSTERYdiva        8
# loveandpeace045     8
# GloriaMondayCom     7
# Tabby__             7
# Twiteriscensor1     7
# AleatoricForest     6
# Germantownrunne     6
# HelloHouseguest     6
# NathanStalder       6
# Paramvir_Thandi     6
# SKComics2           6
# 815wrldtrvlr        5
# AishaM997           5
# AshInWonderland     5
# BadAsh95            5
# EvyWeath            5
# GailieOne           5
# IamDanteB           5
# Name: index, dtype: int64

# %%
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']
tweets_timeline = df.groupby(by=['hour', 'day_of_week'])['created_at'].count()

# %%
midpoint = (tweets_timeline.values.max() - tweets_timeline.values.min()) / 2

plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = "serif"
plt.title('Tweet Heatmap for Drone Discussions', fontsize=24)

ax = (sns.heatmap(tweets_timeline.unstack(),
                  cmap='coolwarm',
                  robust=True,
                  center=midpoint,
                  xticklabels=days_of_week))

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(20)

plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.xlabel('Day of the Week', fontsize=24)
plt.ylabel('Time GMT -5:00', fontsize=24)
ax.get_figure().savefig('heatmap_drones.png')

# %%
user_count = pd.DataFrame()
user_count = user_flat['screen_name'].reset_index(name='Screen Name')
user_count = user_count.groupby('Screen Name')['index'].nunique()
top_25_names = user_count.nlargest(50).reset_index()

# %%
top_25_names
# Out:
# Empty DataFrame
# Columns: [Screen Name, index]
# Index: []

# %%
url = pd.DataFrame()
url = df['url'].reset_index()
url = url.groupby('url')['index'].nunique()
url_list = url.nlargest(50).reset_index()
url_list.to_csv('top50URLs.csv', sep='\t')

# %%
df5 = df_top10.groupby(['lang','created_at']).size().reset_index(name='Number of Tweets')
df7 = df5.set_index(['created_at','lang']).sort_index()
df7 = df7.reset_index(level=[1,0])
df7 = df7.set_index(['created_at'])
df7.index = pd.to_datetime(df7.index, unit='s')
df8 = df7.groupby(['lang']).resample('3H').sum().reset_index()

# %%
df3 = df.groupby(df['created_at'].rename('Date')).size().reset_index(name='Number of Tweets')
df3 = df3.set_index(['Date'])
df3.index = pd.to_datetime(df3.index, unit='s')
df4 = df3.resample('H').sum().reset_index()

# %%
import matplotlib.dates as mdates
sns.set_context("talk")
sns.set_style("darkgrid", {'axes.facecolor':'.95'})
plt.figure(figsize=(24, 12))
plt.rcParams['font.family'] = "serif"
plt.rcParams['timezone'] = 'UTC'
plt.xticks(rotation=45)
lp = sns.lineplot(data=df4, x="Date", y="Number of Tweets", markers=True)
lp.xaxis.set_major_locator(mdates.AutoDateLocator(interval_multiples=True))
lp.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
lp.xaxis.set_minor_locator(mdates.HourLocator())
#lp.xaxis.set_minor_formatter(mdates.DateFormatter('%H'))
lp.tick_params(axis="x", which="major", pad=12)
lp.grid(b=True, which='minor', color='w', linewidth=0.5)
for label in (lp.get_xticklabels() + lp.get_yticklabels()):
    label.set_fontsize(14)
for label in (lp.get_xminorticklabels()):
    label.set_fontsize(10)
    label.set_rotation(45)
g1 = lp.set_title('Volume of tweets about Drones by hour').get_figure()
g1.savefig("Tweets_Hour.png")

# %% [markdown]
# ## Drone Crashmas

# %%
df['text'] = df['text'].str.lower()
df = df[~df['text'].str.contains('iraq|afghanistan|libya|syria|airstrike|soleimani|suleimani|qaeda|terrorist', na=False)]
df.head()
# Out:
#                          id  \
# 415528  1208250774331023360
# 415531  1208250749710417921
# 415532  1208250775421554690
# 415533  1208250804760526848
# 415536  1208250827279884288
#
#                                                      text  \
# 415528  + the movie drones on the the bg, but you don’...
# 415531                               e ba’ mi ooo e jooor
# 415532  from old school weapons (machetes, mechanical ...
# 415533  turkey deploys armed drones to northern cyprus...
# 415536  2019%20drone%20u%20christmas%20giveaway https%...
#
#                                                      user retweeted_status  \
# 415528  {'id': 1206402265734623233, 'id_str': '1206402...              NaN
# 415531  {'id': 747166303, 'id_str': '747166303', 'name...              NaN
# 415532  {'id': 259356502, 'id_str': '259356502', 'name...              NaN
# 415533  {'id': 2202959839, 'id_str': '2202959839', 'na...              NaN
# 415536  {'id': 429947734, 'id_str': '429947734', 'name...              NaN
#
#                                                  entities lang  \
# 415528  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415531  {'hashtags': [], 'urls': [], 'user_mentions': ...   pt
# 415532  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415533  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
# 415536  {'hashtags': [], 'urls': [{'url': 'https://t.c...   en
#
#                       created_at  hour  day_of_week domain  url   screen_name  \
# 415528 2019-12-21 00:00:07-05:00     0            5    NaN  NaN        LVMXSS
# 415531 2019-12-21 00:00:01-05:00     0            5    NaN  NaN  austinkojima
# 415532 2019-12-21 00:00:07-05:00     0            5    NaN  NaN  thatonekimmy
# 415533 2019-12-21 00:00:14-05:00     0            5    NaN  NaN   Dolphin1320
# 415536 2019-12-21 00:00:20-05:00     0            5    NaN  NaN   mostafa_hey
#
#        hashtags
# 415528      NaN
# 415531      NaN
# 415532      NaN
# 415533      NaN
# 415536      NaN

# %%
crashmas = pd.DataFrame()
crashmas = df[df['text'].str.contains('dad|brother|hair|crash|dog|cat|roof|mom|mother|grandmother|grandma|sister|grandfather|grandpa|tree|lake|pond|ocean|lost|crashed|broken|broke|vanished|uncle', na=True)].reset_index()
crashmas = crashmas.loc[crashmas['lang'] == 'en']
crashmas = crashmas[~crashmas['screen_name'].str.contains('mountainherder|faineg', na=False)]
crashmas.shape
# Out:
# (18684, 14)

# %%
crashmas.head()
# Out:
#     index                   id  \
# 1  415554  1208250900118155264
# 2  415567  1208251301336899591
# 4  415636  1208252778352541701
# 5  415644  1208252948595130368
# 6  415655  1208253053456941056
#
#                                                 text  \
# 1  rt @jimmyconwayy19: this conversation was the ...
# 2  #drone hard shell carrying backpack bag case w...
# 4  rt @thehumanxp: drone crashes into the water g...
# 5  rt @moment: maybe it’s just the season, but fe...
# 6  rt @jimmyconwayy19: this conversation was the ...
#
#                                                 user  \
# 1  {'id': 476559000, 'id_str': '476559000', 'name...
# 2  {'id': 904905934417289216, 'id_str': '90490593...
# 4  {'id': 43717976, 'id_str': '43717976', 'name':...
# 5  {'id': 547519952, 'id_str': '547519952', 'name...
# 6  {'id': 2248650770, 'id_str': '2248650770', 'na...
#
#                                     retweeted_status  \
# 1  {'created_at': 'Fri Dec 20 22:34:53 +0000 2019...
# 2                                                NaN
# 4  {'created_at': 'Fri Dec 20 10:00:17 +0000 2019...
# 5  {'created_at': 'Thu Dec 19 16:07:43 +0000 2019...
# 6  {'created_at': 'Fri Dec 20 22:34:53 +0000 2019...
#
#                                             entities lang  \
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 2  {'hashtags': [{'text': 'drone', 'indices': [0,...   en
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 5  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
#
#                  created_at  hour  day_of_week domain  url      screen_name  \
# 1 2019-12-21 00:00:37-05:00     0            5    NaN  NaN        dronetool
# 2 2019-12-21 00:02:13-05:00     0            5    NaN  NaN  _gabrielafialho
# 4 2019-12-21 00:08:05-05:00     0            5    NaN  NaN    Mandy80814996
# 5 2019-12-21 00:08:45-05:00     0            5    NaN  NaN       ToooSavage
# 6 2019-12-21 00:09:10-05:00     0            5    NaN  NaN      Just_kyming
#
#   hashtags
# 1      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 6      NaN

# %%
crashmas.shape
# Out:
# (18684, 14)

# %%
crashmas_2 = crashmas.groupby(crashmas['created_at'].rename('Date')).size().reset_index(name='Number of Tweets')
crashmas_2 = crashmas_2.set_index(['Date'])
crashmas_2.index = pd.to_datetime(crashmas_2.index, unit='s')
crashmas_resampled = crashmas_2.resample('H').sum().reset_index()

import matplotlib.dates as mdates
sns.set_context("talk")
sns.set_style("darkgrid", {'axes.facecolor':'.95'})
plt.figure(figsize=(24, 12))
plt.rcParams['font.family'] = "serif"
plt.rcParams['timezone'] = 'US/Eastern'
plt.xticks(rotation=45)
lp = sns.lineplot(data=crashmas_resampled, x="Date", y="Number of Tweets", markers=True)
lp.xaxis.set_major_locator(mdates.DayLocator())
lp.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
lp.xaxis.set_minor_locator(mdates.HourLocator())
#lp.xaxis.set_minor_formatter(mdates.DateFormatter('%H'))
lp.tick_params(axis="x", which="major", pad=12)
lp.grid(b=True, which='minor', color='w', linewidth=0.5)
for label in (lp.get_xticklabels() + lp.get_yticklabels()):
    label.set_fontsize(14)
for label in (lp.get_xminorticklabels()):
    label.set_fontsize(8)
    label.set_rotation(45)
g1 = lp.set_title('Volume of #dronecrashmas tweets by hour | 2019').get_figure()
g1.savefig("Tweets_Hour_Dads.png")

# %%
#days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']
tweets_timeline = crashmas.groupby(by=['hour', 'day_of_week'])['created_at'].count()

midpoint = (tweets_timeline.values.max() - tweets_timeline.values.min()) / 2

plt.figure(figsize=(20, 15))
plt.rcParams['font.family'] = "serif"
plt.title('Tweet Heatmap for Dronecrashmas Discussions', fontsize=24)

ax = (sns.heatmap(tweets_timeline.unstack(),
                  cmap='coolwarm',
                  robust=True,
                  center=midpoint,
                  xticklabels=days_of_week))

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(20)

plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.xlabel('Day of the Week', fontsize=24)
plt.ylabel('Time GMT -5:00', fontsize=24)
ax.get_figure().savefig('heatmap_drones.png')

# %%
palantir = pd.DataFrame()
palantir = df[df['text'].str.contains('dad', na=True)].reset_index()

# %%
# Out:
#     index                   id  \
# 0  415662  1208253232654540800
# 1  415845  1208257569967476736
# 2  416708  1208276379973885952
# 3  416891  1208280000060891136
# 4  417447  1208290461451837441
#
#                                                 text  \
# 0  RT @vsalben: Comparto mi último trabajo realiz...
# 1  RT @DescubreCuenca: En estas fechas llenas de ...
# 2  Weddings are Satanic rituals to uphold the pat...
# 3  RT @IndraCompany: #Sabíasque Indra Air Drones ...
# 4  RT @asiandaddylover: https://t.co/nJZ0TaJiui h...
#
#                                                 user  \
# 0  {'id': 877097713, 'id_str': '877097713', 'name...
# 1  {'id': 951031271748227078, 'id_str': '95103127...
# 2  {'id': 3775962913, 'id_str': '3775962913', 'na...
# 3  {'id': 769908679, 'id_str': '769908679', 'name...
# 4  {'id': 1058823973339750401, 'id_str': '1058823...
#
#                                     retweeted_status  \
# 0  {'created_at': 'Fri Dec 20 08:37:15 +0000 2019...
# 1  {'created_at': 'Thu Dec 19 11:59:51 +0000 2019...
# 2                                                NaN
# 3  {'created_at': 'Thu Dec 19 08:02:58 +0000 2019...
# 4  {'created_at': 'Fri Nov 29 06:11:48 +0000 2019...
#
#                                             entities lang  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...   es
# 1  {'hashtags': [{'text': 'Cuenca', 'indices': [7...   es
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...   en
# 3  {'hashtags': [{'text': 'Sabíasque', 'indices':...   es
# 4  {'hashtags': [], 'urls': [{'url': 'https://t.c...  und
#
#                  created_at  hour  day_of_week domain  url     screen_name  \
# 0 2019-12-21 00:09:53-05:00     0            5    NaN  NaN  _MicheleAustin
# 1 2019-12-21 00:27:07-05:00     0            5    NaN  NaN         Bluxy91
# 2 2019-12-21 01:41:52-05:00     1            5    NaN  NaN       CateyJo05
# 3 2019-12-21 01:56:15-05:00     1            5    NaN  NaN        AnnTheo5
# 4 2019-12-21 02:37:49-05:00     2            5    NaN  NaN  Joe_Brindley95
#
#   hashtags
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
